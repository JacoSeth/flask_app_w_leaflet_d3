# %%
## I'm the boss, here's what I need

# Create functions that return a table of data for each district/county w/ the following keys:

    # Total Subscribers
    # Total Members
    # Total Users
    # Total Nonmembers
    
# When you're done, work on scaling it up so each district has its own function

# %%
import pandas as pd
data = pd.read_csv('/Users/sethjacobson/Desktop/COLOGOPCL/geocod.io exports/1.16.2020_geocodio_export.csv', engine='python')
coded_df = pd.DataFrame(data)
coded_df.head()
# Out:
#    Unnamed: 0             userId firstName  lastName          emailAddress  \
# 0           0  2Q9ckMAJjL7sqcamx      John   Hancock  admin@caucusroom.com
# 1           1  8LyygB2aaH6kZnaJq     Allen    Fuller  allen@caucusroom.com
# 2           2  ZCMaQmQF4x5o6NTQy     Megan    Hanson  megan@caucusroom.com
# 3           3  c2FTzFZxpTbaa2nx8      Matt  Knoedler   matt@caucusroom.com
# 4           4  XJDsAqrjgos7wdwS8     Kelly     Maher     okmaher@gmail.com
#
#          createDate dateOfBirth       city state     county  ...  \
# 0  2019-06-29 04:27  07/04/1976  Lafayette    CO    BOULDER  ...
# 1  2019-07-03 23:41  04/22/1977  Lafayette    CO    BOULDER  ...
# 2  2019-07-02 23:45  05/15/1989     Golden    CO  JEFFERSON  ...
# 3  2019-07-03 14:46  02/12/1975     Golden    CO  JEFFERSON  ...
# 4  2019-07-08 20:10  03/03/1983   Brighton    CO      ADAMS  ...
#
#            Street       City  State            County      Zip  Country  \
# 0     Diamond Cir  Lafayette     CO    Boulder County  80026.0       US
# 1    Brainard Cir  Lafayette     CO    Boulder County  80026.0       US
# 2  Denver West Dr     Golden     CO  Jefferson County  80401.0       US
# 3      Dogwood Dr     Golden     CO  Jefferson County  80401.0       US
# 4      Downing St   Thornton     CO      Adams County  80602.0       US
#
#              Source  Congressional District State Legislative District House  \
# 0           Boulder                     CO2          State House District 12
# 1           Boulder                     CO2          State House District 12
# 2  Jefferson County                     CO7          State House District 24
# 3  Jefferson County                     CO2          State House District 25
# 4             Adams                     CO6          State House District 34
#
#   State Legislative District Senate
# 0          State Senate District 17
# 1          State Senate District 17
# 2          State Senate District 20
# 3          State Senate District 16
# 4          State Senate District 24
#
# [5 rows x 40 columns]

# %%
# Congressional District
def get_cd_counts(x):
    # Total Subscribers first
    x_district = coded_df['Congressional District'] == f'CO{x}'
    x_district_coded = coded_df[x_district]
    x_district_subscribers_count = coded_df[x_district].shape[0]
    # Next, do Total Members
    x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
    x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
    x_district_m_v = x_district_coded[x_district_members_verified_count]
    x_district_v_m = x_district_coded[x_district_verified_members_count]
    x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
    # Then, do Unverifieds
    x_district_unverified = x_district_coded['roles'] == 'unverified'
    x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
    x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
    x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
    xd_uv = x_district_coded[x_district_unverified]
    xd_uv_m = x_district_coded[x_district_unverified_member]
    xd_m_uv = x_district_coded[x_district_member_unverified]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
    xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
    # Last, do Nonmembers
    x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
    x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
    x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
    x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
    xd_nm_v = x_district_coded[x_district_nonmembers_verified]
    xd_v_nm = x_district_coded[x_district_verified_nonmembers]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
    xd_nm = x_district_coded[x_district_nonmembers]
    xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
    json_object = {}
    keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
    list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
    for key in keys: 
        for value in list_totals: 
            json_object[key] = value 
            list_totals.remove(value) 
            break
    df = pd.DataFrame([json_object])
    return df.to_json(orient='records')

get_cd_counts(3)
# Out:
# '[{"x_district_subscribers_count":105,"x_district_total_members":93,"xd_nm_total":1,"xd_total_unverifieds":9}]'

# %%
def get_sd_counts(x):
    # Total Subscribers first
    x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
    x_district_coded = coded_df[x_district]
    x_district_subscribers_count = coded_df[x_district].shape[0]
    # Next, do Total Members
    x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
    x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
    x_district_m_v = x_district_coded[x_district_members_verified_count]
    x_district_v_m = x_district_coded[x_district_verified_members_count]
    x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
    # Then, do Unverifieds
    x_district_unverified = x_district_coded['roles'] == 'unverified'
    x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
    x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
    x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
    xd_uv = x_district_coded[x_district_unverified]
    xd_uv_m = x_district_coded[x_district_unverified_member]
    xd_m_uv = x_district_coded[x_district_member_unverified]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
    xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
    # Last, do Nonmembers
    x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
    x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
    x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
    x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
    xd_nm_v = x_district_coded[x_district_nonmembers_verified]
    xd_v_nm = x_district_coded[x_district_verified_nonmembers]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
    xd_nm = x_district_coded[x_district_nonmembers]
    xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
    json_object = {}
    keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
    list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
    for key in keys: 
        for value in list_totals: 
            json_object[key] = value 
            list_totals.remove(value) 
            break
    df = pd.DataFrame([json_object])
    return df.to_json(orient='records')
get_sd_counts(24)
# Out:
# '[{"x_district_subscribers_count":36,"x_district_total_members":27,"xd_nm_total":1,"xd_total_unverifieds":5}]'

# %%
def get_hd_counts(x):
    # Total Subscribers first
    x_district = coded_df['State Legislative District House'] == f'State House District {x}'
    x_district_coded = coded_df[x_district]
    x_district_subscribers_count = coded_df[x_district].shape[0]
    # Next, do Total Members
    x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
    x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
    x_district_m_v = x_district_coded[x_district_members_verified_count]
    x_district_v_m = x_district_coded[x_district_verified_members_count]
    x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
    # Then, do Unverifieds
    x_district_unverified = x_district_coded['roles'] == 'unverified'
    x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
    x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
    x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
    xd_uv = x_district_coded[x_district_unverified]
    xd_uv_m = x_district_coded[x_district_unverified_member]
    xd_m_uv = x_district_coded[x_district_member_unverified]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
    xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
    # Last, do Nonmembers
    x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
    x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
    x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
    x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
    xd_nm_v = x_district_coded[x_district_nonmembers_verified]
    xd_v_nm = x_district_coded[x_district_verified_nonmembers]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
    xd_nm = x_district_coded[x_district_nonmembers]
    xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
    json_object = {}
    keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
    list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
    for key in keys: 
        for value in list_totals: 
            json_object[key] = value 
            list_totals.remove(value) 
            break
    df = pd.DataFrame([json_object])
    return df.to_json(orient='records')
get_hd_counts(65)
# Out:
# '[{"x_district_subscribers_count":12,"x_district_total_members":10,"xd_nm_total":0,"xd_total_unverifieds":2}]'

# %%
x=1
for x in range(1,8):
    print(f"""
    @app.route("/cd_{x}")
    def get_cd{x}_counts():
        # Total Subscribers first
        x_district = coded_df['Congressional District'] == f'CO{x}'
        x_district_coded = coded_df[x_district]
        x_district_subscribers_count = coded_df[x_district].shape[0]
        # Next, do Total Members
        x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
        x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
        x_district_m_v = x_district_coded[x_district_members_verified_count]
        x_district_v_m = x_district_coded[x_district_verified_members_count]
        x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
        # Then, do Unverifieds
        x_district_unverified = x_district_coded['roles'] == 'unverified'
        x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
        x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
        x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
        xd_uv = x_district_coded[x_district_unverified]
        xd_uv_m = x_district_coded[x_district_unverified_member]
        xd_m_uv = x_district_coded[x_district_member_unverified]
        xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
        xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
        # Last, do Nonmembers
        x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
        x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
        x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
        x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
        xd_nm_v = x_district_coded[x_district_nonmembers_verified]
        xd_v_nm = x_district_coded[x_district_verified_nonmembers]
        xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
        xd_nm = x_district_coded[x_district_nonmembers]
        xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
        json_object = {{}}
        keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
        list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
        for key in keys: 
            for value in list_totals: 
                json_object[key] = value 
                list_totals.remove(value) 
                break
        df = pd.DataFrame([json_object])
        return df.to_json(orient='records')
    
    """)
    x+=1
# Out:
#     @app.route("/cd_1")
#     def get_cd1_counts():
#         # Total Subscribers first
#         x_district = coded_df['Congressional District'] == f'CO1'
#         x_district_coded = coded_df[x_district]
#         x_district_subscribers_count = coded_df[x_district].shape[0]
#         # Next, do Total Members
#         x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#         x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#         x_district_m_v = x_district_coded[x_district_members_verified_count]
#         x_district_v_m = x_district_coded[x_district_verified_members_count]
#         x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#         # Then, do Unverifieds
#         x_district_unverified = x_district_coded['roles'] == 'unverified'
#         x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#         x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#         x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#         xd_uv = x_district_coded[x_district_unverified]
#         xd_uv_m = x_district_coded[x_district_unverified_member]
#         xd_m_uv = x_district_coded[x_district_member_unverified]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#         xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0]
#         # Last, do Nonmembers
#         x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#         x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#         x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#         x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#         xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#         xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#         xd_nm = x_district_coded[x_district_nonmembers]
#         xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#         json_object = {}
#         keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
#         list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
#         for key in keys:
#             for value in list_totals:
#                 json_object[key] = value
#                 list_totals.remove(value)
#                 break
#         df = pd.DataFrame([json_object])
#         return df.to_json(orient='records')
#
#
#
#     @app.route("/cd_2")
#     def get_cd2_counts():
#         # Total Subscribers first
#         x_district = coded_df['Congressional District'] == f'CO2'
#         x_district_coded = coded_df[x_district]
#         x_district_subscribers_count = coded_df[x_district].shape[0]
#         # Next, do Total Members
#         x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#         x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#         x_district_m_v = x_district_coded[x_district_members_verified_count]
#         x_district_v_m = x_district_coded[x_district_verified_members_count]
#         x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#         # Then, do Unverifieds
#         x_district_unverified = x_district_coded['roles'] == 'unverified'
#         x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#         x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#         x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#         xd_uv = x_district_coded[x_district_unverified]
#         xd_uv_m = x_district_coded[x_district_unverified_member]
#         xd_m_uv = x_district_coded[x_district_member_unverified]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#         xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0]
#         # Last, do Nonmembers
#         x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#         x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#         x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#         x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#         xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#         xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#         xd_nm = x_district_coded[x_district_nonmembers]
#         xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#         json_object = {}
#         keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
#         list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
#         for key in keys:
#             for value in list_totals:
#                 json_object[key] = value
#                 list_totals.remove(value)
#                 break
#         df = pd.DataFrame([json_object])
#         return df.to_json(orient='records')
#
#
#
#     @app.route("/cd_3")
#     def get_cd3_counts():
#         # Total Subscribers first
#         x_district = coded_df['Congressional District'] == f'CO3'
#         x_district_coded = coded_df[x_district]
#         x_district_subscribers_count = coded_df[x_district].shape[0]
#         # Next, do Total Members
#         x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#         x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#         x_district_m_v = x_district_coded[x_district_members_verified_count]
#         x_district_v_m = x_district_coded[x_district_verified_members_count]
#         x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#         # Then, do Unverifieds
#         x_district_unverified = x_district_coded['roles'] == 'unverified'
#         x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#         x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#         x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#         xd_uv = x_district_coded[x_district_unverified]
#         xd_uv_m = x_district_coded[x_district_unverified_member]
#         xd_m_uv = x_district_coded[x_district_member_unverified]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#         xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0]
#         # Last, do Nonmembers
#         x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#         x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#         x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#         x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#         xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#         xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#         xd_nm = x_district_coded[x_district_nonmembers]
#         xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#         json_object = {}
#         keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
#         list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
#         for key in keys:
#             for value in list_totals:
#                 json_object[key] = value
#                 list_totals.remove(value)
#                 break
#         df = pd.DataFrame([json_object])
#         return df.to_json(orient='records')
#
#
#
#     @app.route("/cd_4")
#     def get_cd4_counts():
#         # Total Subscribers first
#         x_district = coded_df['Congressional District'] == f'CO4'
#         x_district_coded = coded_df[x_district]
#         x_district_subscribers_count = coded_df[x_district].shape[0]
#         # Next, do Total Members
#         x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#         x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#         x_district_m_v = x_district_coded[x_district_members_verified_count]
#         x_district_v_m = x_district_coded[x_district_verified_members_count]
#         x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#         # Then, do Unverifieds
#         x_district_unverified = x_district_coded['roles'] == 'unverified'
#         x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#         x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#         x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#         xd_uv = x_district_coded[x_district_unverified]
#         xd_uv_m = x_district_coded[x_district_unverified_member]
#         xd_m_uv = x_district_coded[x_district_member_unverified]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#         xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0]
#         # Last, do Nonmembers
#         x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#         x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#         x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#         x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#         xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#         xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#         xd_nm = x_district_coded[x_district_nonmembers]
#         xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#         json_object = {}
#         keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
#         list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
#         for key in keys:
#             for value in list_totals:
#                 json_object[key] = value
#                 list_totals.remove(value)
#                 break
#         df = pd.DataFrame([json_object])
#         return df.to_json(orient='records')
#
#
#
#     @app.route("/cd_5")
#     def get_cd5_counts():
#         # Total Subscribers first
#         x_district = coded_df['Congressional District'] == f'CO5'
#         x_district_coded = coded_df[x_district]
#         x_district_subscribers_count = coded_df[x_district].shape[0]
#         # Next, do Total Members
#         x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#         x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#         x_district_m_v = x_district_coded[x_district_members_verified_count]
#         x_district_v_m = x_district_coded[x_district_verified_members_count]
#         x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#         # Then, do Unverifieds
#         x_district_unverified = x_district_coded['roles'] == 'unverified'
#         x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#         x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#         x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#         xd_uv = x_district_coded[x_district_unverified]
#         xd_uv_m = x_district_coded[x_district_unverified_member]
#         xd_m_uv = x_district_coded[x_district_member_unverified]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#         xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0]
#         # Last, do Nonmembers
#         x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#         x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#         x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#         x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#         xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#         xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#         xd_nm = x_district_coded[x_district_nonmembers]
#         xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#         json_object = {}
#         keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
#         list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
#         for key in keys:
#             for value in list_totals:
#                 json_object[key] = value
#                 list_totals.remove(value)
#                 break
#         df = pd.DataFrame([json_object])
#         return df.to_json(orient='records')
#
#
#
#     @app.route("/cd_6")
#     def get_cd6_counts():
#         # Total Subscribers first
#         x_district = coded_df['Congressional District'] == f'CO6'
#         x_district_coded = coded_df[x_district]
#         x_district_subscribers_count = coded_df[x_district].shape[0]
#         # Next, do Total Members
#         x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#         x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#         x_district_m_v = x_district_coded[x_district_members_verified_count]
#         x_district_v_m = x_district_coded[x_district_verified_members_count]
#         x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#         # Then, do Unverifieds
#         x_district_unverified = x_district_coded['roles'] == 'unverified'
#         x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#         x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#         x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#         xd_uv = x_district_coded[x_district_unverified]
#         xd_uv_m = x_district_coded[x_district_unverified_member]
#         xd_m_uv = x_district_coded[x_district_member_unverified]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#         xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0]
#         # Last, do Nonmembers
#         x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#         x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#         x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#         x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#         xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#         xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#         xd_nm = x_district_coded[x_district_nonmembers]
#         xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#         json_object = {}
#         keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
#         list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
#         for key in keys:
#             for value in list_totals:
#                 json_object[key] = value
#                 list_totals.remove(value)
#                 break
#         df = pd.DataFrame([json_object])
#         return df.to_json(orient='records')
#
#
#
#     @app.route("/cd_7")
#     def get_cd7_counts():
#         # Total Subscribers first
#         x_district = coded_df['Congressional District'] == f'CO7'
#         x_district_coded = coded_df[x_district]
#         x_district_subscribers_count = coded_df[x_district].shape[0]
#         # Next, do Total Members
#         x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#         x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#         x_district_m_v = x_district_coded[x_district_members_verified_count]
#         x_district_v_m = x_district_coded[x_district_verified_members_count]
#         x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#         # Then, do Unverifieds
#         x_district_unverified = x_district_coded['roles'] == 'unverified'
#         x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#         x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#         x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#         xd_uv = x_district_coded[x_district_unverified]
#         xd_uv_m = x_district_coded[x_district_unverified_member]
#         xd_m_uv = x_district_coded[x_district_member_unverified]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#         xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0]
#         # Last, do Nonmembers
#         x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#         x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#         x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#         x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#         xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#         xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#         xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#         xd_nm = x_district_coded[x_district_nonmembers]
#         xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#         json_object = {}
#         keys = ['x_district_subscribers_count', 'x_district_total_members', 'xd_total_unverifieds', 'xd_nm_total']
#         list_totals = [x_district_subscribers_count, x_district_total_members, xd_total_unverifieds, xd_nm_total]
#         for key in keys:
#             for value in list_totals:
#                 json_object[key] = value
#                 list_totals.remove(value)
#                 break
#         df = pd.DataFrame([json_object])
#         return df.to_json(orient='records')

# %%
# Glossary

# by Function (JS integration) ####################################################

    # Total Accounts ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    
        # Congressional District
#             def cd_total_accounts(x):
#                 x_district = coded_df['Congressional District'] == f'CO{x}'
#                 x_district_count = coded_df[x_district].shape[0]
#                 return x_district_count
        
        # State Senate District
#             def sd_total_accounts(x):
#                 x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
#                 x_district_count = coded_df[x_district].shape[0]
#                 return x_district_count

        # State House District
#             def hd_total_accounts(x):
#                 x_district = coded_df['State Legislative District House'] == f'State House District {x}'
#                 x_district_count = coded_df[x_district].shape[0]
#                 return x_district_count

        # County
#             def county_total_accounts(county):
#                 county_district = coded_df['county'] == f'{county}'
#                 county_district_count = coded_df[county_district].shape[0]
#                 return county_district_count


    # Total Members ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
        
        # Congressional District
#             def cd_total_members(x):
#                 x_district = coded_df['Congressional District'] == f'CO{x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#                 x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#                 x_district_m_v = x_district_coded[x_district_members_verified_count]
#                 x_district_v_m = x_district_coded[x_district_verified_members_count]
#                 x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#                 return x_district_total_members

        # State Senate District
#             def sd_total_members(x):
#                 x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#                 x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#                 x_district_m_v = x_district_coded[x_district_members_verified_count]
#                 x_district_v_m = x_district_coded[x_district_verified_members_count]
#                 x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#                 return x_district_total_members

        # State House District
#             def hd_total_members(x):
#                 x_district = coded_df['State Legislative District House'] == f'State House District {x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#                 x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#                 x_district_m_v = x_district_coded[x_district_members_verified_count]
#                 x_district_v_m = x_district_coded[x_district_verified_members_count]
#                 x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#                 return x_district_total_members

        # County
#             def county_total_members(county):
#                 x_district = coded_df['county'] == f'{county}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
#                 x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
#                 x_district_m_v = x_district_coded[x_district_members_verified_count]
#                 x_district_v_m = x_district_coded[x_district_verified_members_count]
#                 x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
#                 return x_district_total_members


    # Total Unverified ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    
        # Congressional District
#             def cd_total_unverified(x):
#                 x_district = coded_df['Congressional District'] == f'CO{x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_unverified = x_district_coded['roles'] == 'unverified'
#                 x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#                 x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#                 x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#                 xd_uv = x_district_coded[x_district_unverified]
#                 xd_uv_m = x_district_coded[x_district_unverified_member]
#                 xd_m_uv = x_district_coded[x_district_member_unverified]
#                 xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#                 xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
#                 return xd_total_unverifieds

        # State Senate District
#             def sd_total_unverified(x):
#                 x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_unverified = x_district_coded['roles'] == 'unverified'
#                 x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#                 x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#                 x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#                 xd_uv = x_district_coded[x_district_unverified]
#                 xd_uv_m = x_district_coded[x_district_unverified_member]
#                 xd_m_uv = x_district_coded[x_district_member_unverified]
#                 xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#                 xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
#                 return xd_total_unverifieds

        # State House District
#             def hd_total_unverified(x):
#                 x_district = coded_df['State Legislative District House'] == f'State House District {x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_unverified = x_district_coded['roles'] == 'unverified'
#                 x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#                 x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#                 x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#                 xd_uv = x_district_coded[x_district_unverified]
#                 xd_uv_m = x_district_coded[x_district_unverified_member]
#                 xd_m_uv = x_district_coded[x_district_member_unverified]
#                 xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#                 xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
#                 return xd_total_unverifieds

        # County
#             def county_total_unverified(county):
#                 x_district = coded_df['county'] == f'{county}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_unverified = x_district_coded['roles'] == 'unverified'
#                 x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
#                 x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
#                 x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
#                 xd_uv = x_district_coded[x_district_unverified]
#                 xd_uv_m = x_district_coded[x_district_unverified_member]
#                 xd_m_uv = x_district_coded[x_district_member_unverified]
#                 xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
#                 xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
#                 return xd_total_unverifieds

    # Total Nonmembers ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    
        # Congressional District 
#             def cd_total_nonmembers(x):
#                 x_district = coded_df['Congressional District'] == f'CO{x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#                 x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#                 x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#                 x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#                 xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#                 xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#                 xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#                 xd_nm = x_district_coded[x_district_nonmembers]
#                 xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#                 return xd_nm_total

        # State Senate District
#             def sd_total_nonmembers(x):
#                 x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#                 x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#                 x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#                 x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#                 xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#                 xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#                 xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#                 xd_nm = x_district_coded[x_district_nonmembers]
#                 xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#                 return xd_nm_total

        # State House District
#             def hd_total_nonmembers(x):
#                 x_district = coded_df['State Legislative District House'] == f'State House District {x}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#                 x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#                 x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#                 x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#                 xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#                 xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#                 xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#                 xd_nm = x_district_coded[x_district_nonmembers]
#                 xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#                 return xd_nm_total

        # County
#             def county_total_nonmembers(county):
#                 x_district = coded_df['county'] == f'{county}'
#                 x_district_coded = coded_df[x_district]
#                 x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
#                 x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
#                 x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
#                 x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
#                 xd_nm_v = x_district_coded[x_district_nonmembers_verified]
#                 xd_v_nm = x_district_coded[x_district_verified_nonmembers]
#                 xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
#                 xd_nm = x_district_coded[x_district_nonmembers]
#                 xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
#                 return xd_nm_total

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

# %%
# Total Accounts in Congressional District
def cd_total_accounts(x):
    x_district = coded_df['Congressional District'] == f'CO{x}'
    x_district_count = coded_df[x_district].shape[0]
    return x_district_count

# %%
# Total Accounts in State Senate District
def sd_total_accounts(x):
    x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
    x_district_count = coded_df[x_district].shape[0]
    return x_district_count

# %%
# Total Accounts in State House District
def hd_total_accounts(x):
    x_district = coded_df['State Legislative District House'] == f'State House District {x}'
    x_district_count = coded_df[x_district].shape[0]
    return x_district_count

# %%
# Total Accounts in County
def county_total_accounts(county):
    county_district = coded_df['county'] == f'{county}'
    county_district_count = coded_df[county_district].shape[0]
    return county_district_count

# %%
# Total Members in Congressional District
def cd_total_members(x):
    x_district = coded_df['Congressional District'] == f'CO{x}'
    x_district_coded = coded_df[x_district]
    x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
    x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
    x_district_m_v = x_district_coded[x_district_members_verified_count]
    x_district_v_m = x_district_coded[x_district_verified_members_count]
    x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
    return x_district_total_members

# %%
# Total Members in State Senate District
def sd_total_members(x):
    x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
    x_district_coded = coded_df[x_district]
    x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
    x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
    x_district_m_v = x_district_coded[x_district_members_verified_count]
    x_district_v_m = x_district_coded[x_district_verified_members_count]
    x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
    return x_district_total_members

# %%
# Total Members in State House District
def hd_total_members(x):
    x_district = coded_df['State Legislative District House'] == f'State House District {x}'
    x_district_coded = coded_df[x_district]
    x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
    x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
    x_district_m_v = x_district_coded[x_district_members_verified_count]
    x_district_v_m = x_district_coded[x_district_verified_members_count]
    x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
    return x_district_total_members

# %%
# Total Members in County
def county_total_members(county):
    x_district = coded_df['county'] == f'{county}'
    x_district_coded = coded_df[x_district]
    x_district_members_verified_count = x_district_coded['roles'] == 'member,verified'
    x_district_verified_members_count = x_district_coded['roles'] == 'verified,member'
    x_district_m_v = x_district_coded[x_district_members_verified_count]
    x_district_v_m = x_district_coded[x_district_verified_members_count]
    x_district_total_members = x_district_m_v.shape[0] + x_district_v_m.shape[0]
    return x_district_total_members

# %%
# Total Unverifieds in Congressional District
def cd_total_unverified(x):
    x_district = coded_df['Congressional District'] == f'CO{x}'
    x_district_coded = coded_df[x_district]
    x_district_unverified = x_district_coded['roles'] == 'unverified'
    x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
    x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
    x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
    xd_uv = x_district_coded[x_district_unverified]
    xd_uv_m = x_district_coded[x_district_unverified_member]
    xd_m_uv = x_district_coded[x_district_member_unverified]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
    xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
    return xd_total_unverifieds

# %%
# Total Unverifieds in State Senate District
def sd_total_unverified(x):
    x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
    x_district_coded = coded_df[x_district]
    x_district_unverified = x_district_coded['roles'] == 'unverified'
    x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
    x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
    x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
    xd_uv = x_district_coded[x_district_unverified]
    xd_uv_m = x_district_coded[x_district_unverified_member]
    xd_m_uv = x_district_coded[x_district_member_unverified]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
    xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
    return xd_total_unverifieds

# %%
# Total Unverifieds in State House District
def hd_total_unverified(x):
    x_district = coded_df['State Legislative District House'] == f'State House District {x}'
    x_district_coded = coded_df[x_district]
    x_district_unverified = x_district_coded['roles'] == 'unverified'
    x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
    x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
    x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
    xd_uv = x_district_coded[x_district_unverified]
    xd_uv_m = x_district_coded[x_district_unverified_member]
    xd_m_uv = x_district_coded[x_district_member_unverified]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
    xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
    return xd_total_unverifieds

# %%
# Total Unverifieds in County
def county_total_unverified(county):
    x_district = coded_df['county'] == f'{county}'
    x_district_coded = coded_df[x_district]
    x_district_unverified = x_district_coded['roles'] == 'unverified'
    x_district_unverified_member = x_district_coded['roles'] == 'unverified,member'
    x_district_member_unverified = x_district_coded['roles'] == 'member,unverified'
    x_district_unverified_nonmember = x_district_coded['roles'] == 'unverified,nonmember'
    xd_uv = x_district_coded[x_district_unverified]
    xd_uv_m = x_district_coded[x_district_unverified_member]
    xd_m_uv = x_district_coded[x_district_member_unverified]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmember]
    xd_total_unverifieds = xd_uv.shape[0] + xd_uv_m.shape[0] + xd_m_uv.shape[0] + xd_uv_nm.shape[0] 
    return xd_total_unverifieds

# %%
# Total Nonmembers in Congressional District
def cd_total_nonmembers(x):
    x_district = coded_df['Congressional District'] == f'CO{x}'
    x_district_coded = coded_df[x_district]
    x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
    x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
    x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
    x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
    xd_nm_v = x_district_coded[x_district_nonmembers_verified]
    xd_v_nm = x_district_coded[x_district_verified_nonmembers]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
    xd_nm = x_district_coded[x_district_nonmembers]
    xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
    return xd_nm_total

# %%
# Total Nonmembers in State Senate District
def sd_total_nonmembers(x):
    x_district = coded_df['State Legislative District Senate'] == f'State Senate District {x}'
    x_district_coded = coded_df[x_district]
    x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
    x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
    x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
    x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
    xd_nm_v = x_district_coded[x_district_nonmembers_verified]
    xd_v_nm = x_district_coded[x_district_verified_nonmembers]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
    xd_nm = x_district_coded[x_district_nonmembers]
    xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
    return xd_nm_total

# %%
# Total Nonmembers in State House District
def hd_total_nonmembers(x):
    x_district = coded_df['State Legislative District House'] == f'State House District {x}'
    x_district_coded = coded_df[x_district]
    x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
    x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
    x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
    x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
    xd_nm_v = x_district_coded[x_district_nonmembers_verified]
    xd_v_nm = x_district_coded[x_district_verified_nonmembers]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
    xd_nm = x_district_coded[x_district_nonmembers]
    xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
    return xd_nm_total

# %%
# Total Nonmembers in County
def county_total_nonmembers(county):
    x_district = coded_df['county'] == f'{county}'
    x_district_coded = coded_df[x_district]
    x_district_nonmembers_verified = x_district_coded['roles'] == 'nonmember,verified'
    x_district_verified_nonmembers = x_district_coded['roles'] == 'verified,nonmember'
    x_district_unverified_nonmembers = x_district_coded['roles'] == 'unverified,nonmember'
    x_district_nonmembers = x_district_coded['roles'] == 'nonmember'
    xd_nm_v = x_district_coded[x_district_nonmembers_verified]
    xd_v_nm = x_district_coded[x_district_verified_nonmembers]
    xd_uv_nm = x_district_coded[x_district_unverified_nonmembers]
    xd_nm = x_district_coded[x_district_nonmembers]
    xd_nm_total = xd_nm_v.shape[0] + xd_v_nm.shape[0] + xd_uv_nm.shape[0] + xd_nm.shape[0]
    return xd_nm_total
